# %% [markdown]
# # Building a Research Buddy
#
# I want to build a model (+ simple Gradio GUI) that takes a research paper and can answer questions regarding that paper.
#
# ## Notes
#
# ### Relevant Resources
#
# - See my other notebooks: playground and question-answer-project
# - https://huggingface.co/tasks/question-answering
# - https://huggingface.co/datasets/taesiri/arxiv_qa
# - https://huggingface.co/learn/nlp-course/en/chapter7/3?fw=pt domain adaptation: fine-tune task-agnostic base model for a specific domain
# - https://huggingface.co/learn/nlp-course/chapter7/4?fw=pt Translation - similar to generative Q&A
#
#
# ### Specification & Ideas
#
# - I want generative/abstractive Q&A, not just extractive.
# - I want a closed-domain model, specialized on research. I could do that with domain adaptation. But that can come afterwards.
# - I might want to try RAG models that can access other research papers for context. For now, I can provide suitable context myself.
# - I might want to try document Q&A that also visually inspects papers to answer questions, eg, regarding title, author, or figures.
#
# ### Other Notes
#
# > Encoder-only models like BERT tend to be great at extracting answers to factoid questions like “Who invented the Transformer architecture?” but fare poorly when given open-ended questions like “Why is the sky blue?” In these more challenging cases, encoder-decoder models like T5 and BART are typically used to synthesize the information in a way that’s quite similar to text summarization.
#
# GPT models are decoder-only models, where the decoder takes the input directly and was trained to perform similar tasks to typical encoder-decoder models: https://community.openai.com/t/is-gpt-group-of-models-decoder-only-model/286586/2
#
# It seems like I need a suitable data set to fine-tune a pretrained model.
# The ones from "question-answering" and the tutorial are trained on SQuAD data, where answers are intentionally spans of text.
# I'd need something similar but with generated answers + use a suitable base model with decoder?
#
# ### Existing models
#
# Smaller, pre-trained models for abstractive/generative QA:
#
# - https://huggingface.co/tuner007/t5_abs_qa --> Problem: Max sequence length 512 (short paper has already >4000 tokens)
# - https://huggingface.co/consciousAI/question-answering-generative-t5-v1-base-s-q-c --> Similar issue of too short sequence length
#
# Large, pretrained instruct models:
#
# - Microsoft Phi3mini: Good answers, but too large and slow.
#
# I moved the corresponding code to `question-answering-project.ipynb` because it is too slow. I want to keep this notebook small enough to run entirely in reasonable time.
#
# ## Starting with simple, extractive Q&A

# %%
# Read PDF
from pathlib import Path
from typing import Union

from pypdf import PdfReader


def get_text_from_pdf(pdf_file: Union[str, Path]) -> str:
    """Read the PDF from the given path and return a string with its entire content."""
    reader = PdfReader(pdf_file)

    # Extract text from all pages
    full_text = ""
    for page in reader.pages:
        full_text += page.extract_text()
    return full_text


full_text = get_text_from_pdf("author_version.pdf")
full_text
# Out:
# 'mobile-env: An Open Platform for Reinforcement\nLearning in Wireless Mobile Networks\nStefan Schneider, Stefan Werner\nPaderborn University, Germany\n{stschn, stwerner}@mail.upb.de\nRamin Khalili, Artur Hecker\nHuawei Technologies, Germany\n{ramin.khalili, artur.hecker}@huawei.com\nHolger Karl\nHasso Plattner Institute,\nUniversity of Potsdam, Germany\nholger.karl@hpi.de\nAbstract—Recent reinforcement learning approaches for con-\ntinuous control in wireless mobile networks have shown im-\npressive results. But due to the lack of open and compatible\nsimulators, authors typically create their own simulation en-\nvironments for training and evaluation. This is cumbersome\nand time-consuming for authors and limits reproducibility and\ncomparability, ultimately impeding progress in the ﬁeld.\nTo this end, we proposemobile-env, a simple and open platform\nfor training, evaluating, and comparing reinforcement learning\nand conventional approaches for continuous control in mobile\nwireless networks. mobile-env is lightweight and implements\nthe common OpenAI Gym interface and additional wrappers,\nwhich allows connecting virtually any single-agent or multi-agent\nreinforcement learning framework to the environment. While\nmobile-env provides sensible default values and can be used out\nof the box, it also has many conﬁguration options and is easy to\nextend. We therefore believe mobile-env to be a valuable platform\nfor driving meaningful progress in autonomous coordination of\nwireless mobile networks.\nIndex Terms—wireless mobile networks, network manage-\nment, continuous control, autonomous coordination, reinforce-\nment learning, gym environment, simulation, open source\nI. I NTRODUCTION\nThere is an ongoing trend towards self-learning and self-\nadapting approaches for continuous control and coordination\nin networking [1]. Examples are self-learning approaches for\nmanagement in wired networks [2] but also for cell selection or\npower control in wireless mobile networks [3], [5]. In contrast\nto conventional approaches (e.g., heuristics or mixed-integer\nlinear programs), such self-learning approaches use reinforce-\nment learning or contextual bandits, trained on simulation\nenvironments, to adapt to various scenarios autonomously\nwithout requiring expert or a priori knowledge [1].\nWhile there are existing network simulators (Sec. III), they\nare often not directly compatible with typical reinforcement\nlearning frameworks requiring the OpenAI Gym interface [6].\nThey are also rather cumbersome to set up and conﬁgure,\npreventing fast prototyping of new self-learning approaches.\nTherefore, many authors currently resort to creating their own\nenvironments when designing and publishing a new rein-\nforcement learning approach. Creating a suitable simulation\nenvironment is time-consuming and error-prone, slowing down\nauthors in their research. It is also more difﬁcult for others to\ninterpret and compare published approaches if they each rely\non different simulation environments. Often, the corresponding\nenvironment is not publicly available, making reproduction\nand reuse of the published approach impossible. These limita-\ntions severely hinder comparability and meaningful progress in\nthe ﬁeld of autonomous control for wireless mobile networks.\nTo mitigate these problems, we propose mobile-env, which\nis a simple and open platform for training, evaluating,\nand comparing coordination approaches, particularly suitable\nfor wireless mobile networks. The mobile-env platform is\nlightweight and fast, simple to install and use, written purely\nin Python, and compatible to existing reinforcement learn-\ning frameworks by complying with the OpenAI Gym inter-\nface. Besides novel self-learning approaches, mobile-env also\nsupports existing conventional approaches, facilitating their\nevaluation and comparison. To encourage adoption by the\ncommunity, mobile-env is open source [7], available on the\nofﬁcial Python package in ...

# %%
# Use a question answering pipeline from Hugging Face for answering questions
from transformers import pipeline

question_answerer = pipeline("question-answering")
# This uses a BERT-style model (encode-only), which apparently is better for factoid questions and extractive answers.
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 564e9b5 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use mps:0

# %%
question = "What are benefits of mobile-env over other simulators?"
question_answerer(question, full_text)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/llm/lib/python3.12/site-packages/transformers/pipelines/question_answering.py:391: FutureWarning: Passing a list of SQuAD examples to the pipeline is deprecated and will be removed in v5. Inputs should be passed using the `question` and `context` keyword arguments instead.
#   warnings.warn(
# {'score': 0.4261030852794647,
#  'start': 6110,
#  'end': 6162,
#  'answer': 'easy adoption and fast\nprototyping of new approaches'}

# %%
question_answerer("Is mobile-env open source?", full_text)
# Out:
# {'score': 0.30191317200660706,
#  'start': 3868,
#  'end': 3879,
#  'answer': 'open source'}

# %%
question_answerer("Who is the best person in the world?", full_text)
# Out:
# {'score': 0.0010773177491500974,
#  'start': 12170,
#  'end': 12184,
#  'answer': 'Brunori et al.'}

# %%
question_answerer("Which programming language is mobile-env written in?", full_text)
# really bad
# Out:
# {'score': 0.9728466868400574, 'start': 3552, 'end': 3558, 'answer': 'Python'}

# %%
# Trying Q&A with a different model - RoBERTa
# https://huggingface.co/deepset/tinyroberta-squad2
from transformers import AutoModelForQuestionAnswering, AutoTokenizer, pipeline

model_name = "deepset/tinyroberta-squad2"
roberta_qa = pipeline("question-answering", model=model_name, tokenizer=model_name)
# Out:
# Device set to use mps:0

# %%
question = "What are benefits of mobile-env over other simulators?"
roberta_qa(question, full_text)
# That's still extractive! - it's still BERT-based (only encoder, no decorder). BART would be encode-decoder
# Out:
# {'score': 0.48334258794784546,
#  'start': 12891,
#  'end': 12908,
#  'answer': 'far more features'}

# %%
roberta_qa("Which programming language is mobile-env written in?", full_text)
# Better answer than the model above.
# Out:
# {'score': 0.9660436511039734, 'start': 3552, 'end': 3558, 'answer': 'Python'}

# %%
roberta_qa("Who is the best person in the world?", full_text)
# Out:
# {'score': 6.944365793515317e-08,
#  'start': 17073,
#  'end': 17100,
#  'answer': 'A. Medeisis and A. Kajackas'}

# %% [markdown]
# ## Generative/Abstractive QA with existing models
#
# Seems like this falls more under the Text2Text Generation, where question and context are given as one input text, separated by keywords.
#
# ### Exploring available models
#
# #### Basic T5 without specific Q&A fine-tuning: google/flan-t5-small or -base
#
# https://huggingface.co/google/flan-t5-small
#
# > If you already know T5, FLAN-T5 is just better at everything. For the same number of parameters, these models have been fine-tuned on more than 1000 additional tasks covering also more languages

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration

tokenizer = T5Tokenizer.from_pretrained("google/flan-t5-small")
model = T5ForConditionalGeneration.from_pretrained("google/flan-t5-small")

input_text = "translate English to German: How old are you?"
input_ids = tokenizer(input_text, return_tensors="pt").input_ids

outputs = model.generate(input_ids)
print(tokenizer.decode(outputs[0]))
# Out:
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# <pad> Wie ich er bitten?</s>

# %%
context = "In Norse mythology, Valhalla is a majestic, enormous hall located in Asgard, ruled over by the god Odin."
question = "What is Valhalla?"
input_text = f"{context} Please answer the following question: {question}"

input_ids = tokenizer(input_text, return_tensors="pt").input_ids

outputs = model.generate(input_ids)
print(tokenizer.decode(outputs[0]))

# Doesn't work at all for generative Q&A (same for larger google/flan-t5-base model)
# Out:
# <pad> hall</s>

# %% [markdown]
# Instead, let's check out some fine-tuned T5 models for generative/abstractive QA.
#
# #### consciousAI/question-answering-generative-t5-v1-base-s-q-c
#
# https://huggingface.co/consciousAI/question-answering-generative-t5-v1-base-s-q-c

# %%
# https://huggingface.co/consciousAI/question-answering-generative-t5-v1-base-s-q-c
consciousai_pipeline = pipeline("text2text-generation", model="consciousAI/question-answering-generative-t5-v1-base-s-q-c")

def get_answer_consciousai(question: str, context: str) -> str:
    # The syntax for separating question and context is model-specific, depending on how it was fine-tuned.
    query = f"question: {question}</s> question_context: {context}"
    return consciousai_pipeline(query)
# Out:
# Device set to use mps:0

# %%
# Short query --> good answer
context = "In Norse mythology, Valhalla is a majestic, enormous hall located in Asgard, ruled over by the god Odin."
question = "What is Valhalla?"
get_answer_consciousai(question, context)
# Out:
# [{'generated_text': 'a majestic, enormous hall'}]

# %%
# Long query with full text from paper --> too long, but okayish answer
question = "What are benefits of mobile-env over other simulators?"
get_answer_consciousai(question, full_text)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (4355 > 512). Running this sequence through the model will result in indexing errors
# [{'generated_text': 'a simple and lightweight simulation environment'}]

# %% [markdown]
# #### tuner007/t5_abs_qa
#
# https://huggingface.co/tuner007/t5_abs_qa
#
# Also sequence length of max 512

# %%
# Setup from https://huggingface.co/tuner007/t5_abs_qa
import torch
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

model_name: str = "tuner007/t5_abs_qa"
tokenizer_tuner = AutoTokenizer.from_pretrained(model_name)
model_tuner = AutoModelForSeq2SeqLM.from_pretrained(model_name)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

def get_answer_tuner(question: str, context: str) -> str:
    """Generate an answer for the given question based on the given context."""
    # Here, context and question are separated by different keywords than in the model before
    input_text = f"context: {context} <question for context: {question} </s>"
    features = tokenizer_tuner([input_text], return_tensors='pt')
    out = model_tuner.generate(input_ids=features['input_ids'].to(device), attention_mask=features['attention_mask'].to(device))
    return tokenizer_tuner.decode(out[0])
# Out:
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Error while downloading from https://cdn-lfs.hf.co/tuner007/t5_abs_qa/d99167d589bc86ff15cd58eaf80f249e4815ff0b6a9a78e2067af2c9d9ea0b42?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27model.safetensors%3B+filename%3D%22model.safetensors%22%3B&Expires=1738695217&Policy=&Signature=i%7EKdISMDNJcQsneI-cQKmynrAaMfXsLWrW54sCdjXnU4vEl52jtqCb8KwUUTw5shDzLc82tg3%7EDl3dymS5PAt8-hFG2tGNHAG8vL7f6-F654Jv5jQQpm%7EB2Eb9x8KYfTVwO7eEr6HluSITsH7nG33QTI2w%7EC8cpPRX-gQb9rh%7EwMcA3jAaGx%7ErwvPSO6zoCj9Dtd8HAOTZRBouEXNXiJDKSEbJChA%7EzQttVkFwk--CvPTFFGhaR7KD-cBZqfsmkxbsNefcfRfcxrUFZaEsyZ%7EllXtnzQEy89YaJeY%7E5RV6tMgUDUpNvvjA0Uyx-gvugI9gHAuIVaEg0sScFWAzawPg__&Key-Pair-Id=K3RPWS32NSSJCE: HTTPSConnectionPool(host='cdn-lfs.hf.co', port=443): Read timed out.
# Trying to resume download...

# %%
context = "In Norse mythology, Valhalla is a majestic, enormous hall located in Asgard, ruled over by the god Odin."
question = "What is Valhalla?"
get_answer_tuner(question, context)
# Out:
# model.safetensors:   0%|          | 0.00/1.19G [00:00<?, ?B/s]
# '<pad> Valhalla is a hall of worship that is ruled by the god Odin.</s>'

# %%
# Illustrate how the model returns tokens that are then decoded into words by the decoder:
input_text = f"context: {context} <question for context: {question} </s>"
features = tokenizer_tuner([input_text], return_tensors='pt')
out_tokens = model_tuner.generate(input_ids=features['input_ids'].to(device), attention_mask=features['attention_mask'].to(device))
out_tokens
# Out:
# tensor([[    0,  3833, 11516,     9,    19,     3,     9,  6358,    13,  7373,
#             24,    19,     3, 16718,    57,     8,  8581,  9899,    77,     5,
#              1]])

# %%
for token in out_tokens[0]:
    print(f"Token: {token}, decoded: {tokenizer_tuner.decode(token)}")
# Out:
# Token: 0, decoded: <pad>
# Token: 3833, decoded: Val
# Token: 11516, decoded: hall
# Token: 9, decoded: a
# Token: 19, decoded: is
# Token: 3, decoded:
# Token: 9, decoded: a
# Token: 6358, decoded: hall
# Token: 13, decoded: of
# Token: 7373, decoded: worship
# Token: 24, decoded: that
# Token: 19, decoded: is
# Token: 3, decoded:
# Token: 16718, decoded: ruled
# Token: 57, decoded: by
# Token: 8, decoded: the
# Token: 8581, decoded: god
# Token: 9899, decoded: Od
# Token: 77, decoded: in
# Token: 5, decoded: .
# Token: 1, decoded: </s>

# %%
# Can achieve the same with a simple pipeline (as with the model above)
tuner_pipeline = pipeline("text2text-generation", model="tuner007/t5_abs_qa")
tuner_pipeline(input_text)
# Out:
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use mps:0
# [{'generated_text': 'Valhalla is a hall of worship that is ruled by the god Odin.'}]

# %%
question = "What are benefits of mobile-env over other simulators?"
get_answer_tuner(question, full_text)
# Sequence length too short --> Explicitly outputs if no answer is available in the given context
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (4357 > 512). Running this sequence through the model will result in indexing errors
# '<pad> No answer available in context</s>'

# %% [markdown]
# #### MaRiOrOsSi/t5-base-finetuned-question-answering
#
# https://huggingface.co/MaRiOrOsSi/t5-base-finetuned-question-answering
#
# This is the most downloaded T5 finetuned for Q&A.
# Also sequence length 512

# %%
from  transformers  import  AutoTokenizer, AutoModelForSeq2SeqLM
# from transformers.generation import GenerateEncoderDecoderOutput

model_name = "MaRiOrOsSi/t5-base-finetuned-question-answering"
tokenizer_mario = AutoTokenizer.from_pretrained(model_name)
model_mario = AutoModelForSeq2SeqLM.from_pretrained(model_name)

def get_answer_mario(question: str, context: str) -> str:
    """Generate an answer for the given question based on the given context.
    
    Using the MaRiOrOsSi/t5-base-finetuned-question-answering model.
    """
    # Again different separation of question and context
    input = f"question: {question} context: {context}"
    encoded_input = tokenizer_mario([input], return_tensors='pt')
    # Can get scores per token if I output a GenerateEncoderDecoderOutput with return_dict_in_generate=True, output_scores=True
    output = model_mario.generate(input_ids=encoded_input.input_ids, attention_mask=encoded_input.attention_mask) #, return_dict_in_generate=True, output_scores=True)

    # Can instruct the tokenizer to skip special tokens that indicate sequence start and end
    return tokenizer_mario.decode(output[0], skip_special_tokens=True)

# %%
question = "What is Valhalla?"
context = "In Norse mythology, Valhalla is a majestic, enormous hall located in Asgard, ruled over by the god Odin."
get_answer_mario(question, context)
# Out:
# 'A majestic, enormous hall'

# %% [markdown]
# ### Answer questions for entire document (longer than context)
#
# #### Split full text into shorter sequences

# %%
# Split the full text into smaller parts such that the max token length is not exceeded.
import math

for tokenizer in (tokenizer_tuner, tokenizer_mario):
    num_tokens_total: int = len(tokenizer([full_text])["input_ids"][0])
    print(f"Tokens in full text: {num_tokens_total}")
    print(f"Max tokens supported by model: {tokenizer.model_max_length}")
    print(f"--> Split full text into {math.ceil(num_tokens_total / tokenizer.model_max_length)} parts.")
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (4334 > 512). Running this sequence through the model will result in indexing errors
# Tokens in full text: 4334
# Max tokens supported by model: 512
# --> Split full text into 9 parts.
# Tokens in full text: 4334
# Max tokens supported by model: 512
# --> Split full text into 9 parts.

# %%
# Have same max tokens of 512 for all models --> Split text into 9 parts
def split_text_into_parts(full_text: str, num_parts: int) -> list[str]:
    """Split the given full text into a list of equally sized parts."""
    len_per_part: int = int(len(full_text) / num_parts)
    return [full_text[i * len_per_part : (i+1) * len_per_part] for i in range(num_parts)]

text_parts = split_text_into_parts(full_text, num_parts=9)
text_parts
# Out:
# ['mobile-env: An Open Platform for Reinforcement\nLearning in Wireless Mobile Networks\nStefan Schneider, Stefan Werner\nPaderborn University, Germany\n{stschn, stwerner}@mail.upb.de\nRamin Khalili, Artur Hecker\nHuawei Technologies, Germany\n{ramin.khalili, artur.hecker}@huawei.com\nHolger Karl\nHasso Plattner Institute,\nUniversity of Potsdam, Germany\nholger.karl@hpi.de\nAbstract—Recent reinforcement learning approaches for con-\ntinuous control in wireless mobile networks have shown im-\npressive results. But due to the lack of open and compatible\nsimulators, authors typically create their own simulation en-\nvironments for training and evaluation. This is cumbersome\nand time-consuming for authors and limits reproducibility and\ncomparability, ultimately impeding progress in the ﬁeld.\nTo this end, we proposemobile-env, a simple and open platform\nfor training, evaluating, and comparing reinforcement learning\nand conventional approaches for continuous control in mobile\nwireless networks. mobile-env is lightweight and implements\nthe common OpenAI Gym interface and additional wrappers,\nwhich allows connecting virtually any single-agent or multi-agent\nreinforcement learning framework to the environment. While\nmobile-env provides sensible default values and can be used out\nof the box, it also has many conﬁguration options and is easy to\nextend. We therefore believe mobile-env to be a valuable platform\nfor driving meaningful progress in autonomous coordination of\nwireless mobile networks.\nIndex Terms—wireless mobile networks, network manage-\nment, continuous control, autonomous coordination, reinforce-\nment learning, gym environment, simulation, open source\nI. I NTRODUCTION\nThere is an ongoing trend towards self-learning and self-\nadapting approaches for continuous control and coordination\nin networking [1]. Examples are self-learning approaches for\nmanagement in wired networks [2] but also for cell selection or\npower control in wireless mobile networks [3], [5]. In contrast\nto conventio',
#  'nal approaches (e.g., heuristics or mixed-integer\nlinear programs), such self-learning approaches use reinforce-\nment learning or contextual bandits, trained on simulation\nenvironments, to adapt to various scenarios autonomously\nwithout requiring expert or a priori knowledge [1].\nWhile there are existing network simulators (Sec. III), they\nare often not directly compatible with typical reinforcement\nlearning frameworks requiring the OpenAI Gym interface [6].\nThey are also rather cumbersome to set up and conﬁgure,\npreventing fast prototyping of new self-learning approaches.\nTherefore, many authors currently resort to creating their own\nenvironments when designing and publishing a new rein-\nforcement learning approach. Creating a suitable simulation\nenvironment is time-consuming and error-prone, slowing down\nauthors in their research. It is also more difﬁcult for others to\ninterpret and compare published approaches if they each rely\non different simulation environments. Often, the corresponding\nenvironment is not publicly available, making reproduction\nand reuse of the published approach impossible. These limita-\ntions severely hinder comparability and meaningful progress in\nthe ﬁeld of autonomous control for wireless mobile networks.\nTo mitigate these problems, we propose mobile-env, which\nis a simple and open platform for training, evaluating,\nand comparing coordination approaches, particularly suitable\nfor wireless mobile networks. The mobile-env platform is\nlightweight and fast, simple to install and use, written purely\nin Python, and compatible to existing reinforcement learn-\ning frameworks by complying with the OpenAI Gym inter-\nface. Besides novel self-learning approaches, mobile-env also\nsupports existing conventional approaches, facilitating their\nevaluation and comparison. To encourage adoption by the\ncommunity, mobile-env is open source [7], available on the\nofﬁcial Python package index (PyPI), comes with sensible\ndefault values yet extensive conﬁguration o',
#  'ptions, and is well\ndocumented. Thanks to its modular architecture, it is also easy\nto adjust and extend (Sec. II). With mobile-env, we hope to\nprovide a useful tool for prototyping, training, and evaluating\nnew approaches as well as for benchmarking and comparing\nexisting approaches.\nII. T HE mobile-env PLATFORM\nmobile-env is a minimalist and lightweight simulation plat-\nform that can serve as training and evaluation environment\nfor reinforcement learning and other control algorithms in\nwireless mobile networks. Sec. II-A outlines our design goals.\nSec. II-B describes the simulation procedure and interaction\nwith an agent through the OpenAI Gym interface, pointing\nout common challenges and our approaches to address them.\nSec. II-C presents the resulting architecture.\nA. Design Goals\nCurrent simulation environments are typically either tailored\nto a speciﬁc use case [8], [9] or versatile, generic network sim-\nulation frameworks [10], [11] (detailed in Sec. III). Custom-\ntailored simulation environments are ideal to quickly prototype\nnew approaches in a speciﬁc use case but are difﬁcult to adjust\nand extend to other scenarios. Generic network simulators pro-\nvide a wealth of features and conﬁguration options, allowing\nﬁne-grained simulation of many different scenarios but also\nrequiring signiﬁcant overhead for modeling each new scenario\nand additional effort for integrating self-learning approaches.\n© 2022 IEEE. Personal use of this material is permitted. Permission from IEEE must be obtained for all other uses,\nin any current or future media, including reprinting/republishing this material for advertising or promotional purposes,\ncreating new collective works, for resale or redistribution to servers or lists,\nor reuse of any copyrighted component of this work in other works.OpenAI Gym\nAgent\nWrappers\nCore Simulation Logic\nHandlers\nFig. 1: mobile-env simulation procedure.\nWith mobile-env we aim to ﬁll the gap between these\ntwo sides of the spectrum. Our goal is to keep',
#  ' mobile-\nenv simple and lightweight with sensible default values and\npredeﬁned example scenarios, enabling easy adoption and fast\nprototyping of new approaches. At the same time, we aim at\nconﬁgurability and extensibility, allowing users to customize\nall aspects of the simulation environment with low overhead to\nexperiment with different scenarios and address their speciﬁc\nuse cases. Core to this conﬁgurability and extensibility are\nthe many provided conﬁguration options and the modular\narchitecture (Sec. II-C).\nB. Simulation Procedure\nWhen training and evaluating self-learning approaches, the\ncontrol agent repeatedly interacts with the simulation envi-\nronment, typically through the standardized OpenAI Gym\ninterface [6]. Fig. 1 illustrates this simulation procedure, where\nthe agent obtains an observation oi−1 of the environment’s\ncurrent state at time ti−1 and selects an action ai−1 to\ncontrol the environment (e.g., cell selection, power control,\nscheduling, ...). This action is applied to the environment,\naffects its state, and leads to a new observation oi and a\nreward ri at time ti.\nAuthors wanting to devise and prototype new self-learning\napproaches often face multiple challenges: How do they\nquickly set up the environment’s simulation logic? How do\nthey integrate the learning agent with the simulation loop?\nHow do they customize the environment to experiment with\ndifferent scenarios and with varying observations, actions, and\nreward, which are crucial to reinforcement learning? How\ndo they deal with multi-agent scenarios and with different\navailable reinforcement learning frameworks?\nmobile-env addresses these challenges in different ways:\nThe core simulation logic is inside the environment’s step\nfunction (as deﬁned by OpenAI Gym), which takes an action,\napplies it to the environment, progresses simulation time,\nand returns the next observation and reward. We call step\nperiodically rather than event-based to let the agent decide\nitself for each time step wheth',
#  'er to take an action or to choose\na no-op. An exemplary use case of mobile-env is multi-cell\nselection for scenarios with coordinated multipoint (CoMP),\nwhere users can connect to more than one serving cell\nsimultaneously for higher data rates or improved coverage.\nHere, the action deﬁnes which cells to (dis-)connect, and\nthe step function applies these actions and updates users’\nmobile-env \nCore\nbase\nentities\nmovement \nchannel\nschedule\nHandlers\nabstract\nsingle-agent\nmulti-agent\nobs., actions,\nreward\nScenarios\nsmall\nmedium\nlarge\n...\nWrappers\nRay RLlib\nPettingZoo\n...\nOpenAI GymRay \nRLlib\nstable-\nbaselines\nMava\nOpenAI \nBaselines\n... \nFig. 2: mobile-env modular architecture.\nconnections, positions, data rates, etc. To this end, it leverages\nrealistic realistic models for path loss (Okumura-Hata [12]),\nuser mobility (improved random waypoint [13]), scheduling\n(e.g., proportional-fair), etc., which are included in mobile-\nenv and can be replaced, customized, and extended freely.\nFor other use cases, e.g., power control or scheduling, these\nmodels can be replaced by the agent’s actions. To facilitate\nquick prototyping, mobile-env comes with predeﬁned example\nscenarios and all conﬁguration options have sensible defaults.\nIn addition to providing the core simulation logic, mobile-\nenv also introduces “handlers”, which allow customizing ob-\nservations, actions, and reward easily and “wrappers” to align\nthe environment to interfaces other than OpenAI Gym, e.g.,\nfor multi-agent learning (detailed in Sec. II-C).\nC. Modular Architecture\nWe built mobile-env in a modular, object-oriented fashion.\nFig. 2 illustrates the architecture consisting of four main\npackages: core, scenarios, handlers, and wrappers. The core\npackage contains all main functionality and simulation logic,\ne.g., modeling properties of users and base stations (entities)\nor implementing different algorithms for scheduling resources\nto connected users (scheduling). It also implements rendering\nfunctionality to visua',
#  'lize learned policies, e.g., when running\ninside a Jupyter notebook. Each of these core modules contains\nclasses that can be extended easily through inheritance and by\noverwriting the desired attributes or methods. The scenarios\npackage contains predeﬁned conﬁgurations, currently for a\nsmall, medium, and large scenario, i.e., for cell selection with\ndifferent numbers of users and cells.. Over time, we plan to\ninclude more and more predeﬁned scenarios, depending on\nfeedback and contributions by the community. Each scenario\nis versioned and registered as Gym environment such that it\ncan be used out of the box after importing mobile-env (e.g.,\ngym.make("mobile-medium-central-v0")).\nAs described in Sec. II-B, mobile-env implements the\ncommon OpenAI Gym interface with its step function [6].\nRather than hard-wiring speciﬁc observations, actions, and\nrewards inside step, they are conﬁgurable through handlers.\nA handler class has full access to the environment state,\ndeﬁnes the observation and action space, and is called by\nstep to process actions, calculate rewards, and return new\nobservations. mobile-env already provides example handlersfor both single-agent and multi-agent approaches, which can\nbe sub-classed, adjusted, and extended.\nSome reinforcement learning frameworks deviate from the\nstandard OpenAI Gym interface, e.g., for multi-agent ap-\nproaches. Here, wrapper classes wrap the Gym interface and\ntransform observations, actions, or reward into the desired\nformat but, unlike handlers, do not change their meaning. We\nprovide a wrapper for multi-agent learning with the popular\nRay RLlib framework [14], which, for example, expects the\nobservation space to be deﬁned per agent, not combined for\nall agents. Through the OpenAI Gym interface and these\nwrappers, researchers can connect their approaches based on\nvirtually any framework to mobile-env and leverage it for fast\nand simple training and evaluation.\nIII. C OMPARISON AGAINST OTHER PLATFORMS\nmobile-env is inspired by h',
#  'ighway-env [9], which is\nalso a simple and lightweight environment for reinforcement\nlearning but considers autonomous driving instead of wireless\nmobile networks. Brunori et al. [8] propose a related platform\nfor multi-agent reinforcement learning in wireless networks\nbut focuses on autonomous unmanned aerial vehicles (UA Vs).\nBesides, their platform has little documentation and examples\nand is limited by an overly restrictive, custom license, denying\nopen-source use, modiﬁcation, or redistribution. In contrast,\nmobile-env is more ﬂexible, better documented, and licensed\nby the standard, permissive MIT license, allowing private and\ncommercial use, modiﬁcation, and distribution.\nOn the other side of the spectrum, there are established,\ngeneric network simulators like ns-3 [10] or OMNeT++ [11],\nwhich are very ﬂexible and model networking in detail. These\nsimulators provide far more features than mobile-env, but their\nﬂexibility comes at the cost of increased complexity and over-\nhead when testing many different scenarios and approaches.\nmobile-env can be installed quickly with a single command\n(pip install mobile-env; 25 kB) and can train or\nevaluate a reinforcement learning agent in less than 10 lines\nof Python code. In contrast, OMNeT++ requires deﬁning\nthe structure of the desired simulation environment in NED\nlanguage within a custom IDE, then implementing its logic\nin various C++ classes, then parametrizing it in a separate\nomnetpp.ini ﬁle, and ﬁnally building and compiling it,\nbefore the simulation is ready to run. At this point, the\nsimulation still lacks the interaction with the reinforcement\nlearning agent through the OpenAI Gym interface (Python)—a\nconsiderable, often prohibitive overhead for researchers. While\nthere is an OpenAI Gym implementation for ns-3 [15], the\ncomplexity and overhead are still comparable to OMNeT++.\nIn comparison, mobile-env represents an intermediate solu-\ntion with reasonable features and ﬂexibility, built-in single-\nand multi-agent',
#  ' support via OpenAI Gym and wrappers, as\nwell as fast and simple installation and usage.\nIV. D EMONSTRATION\nWe demonstrate mobile-env, we provide an interactive\nJupyter notebook, which others can experiment with at their\nown pace. 1 In this demonstration, we show how to set up\nmobile-env, illustrate the predeﬁned default scenarios, and\noptions for conﬁguration and extension (e.g., regarding the\nnumber and movement of simulated users and the observation\nor action space). We also demonstrate how to connect different\nreinforcement learning frameworks to mobile-env for training\nand visualizing single-agent and multi-agent approaches.\nV. C ONCLUSION\nWith mobile-env we propose an open and simple yet conﬁg-\nurable platform for reinforcement learning in wireless mobile\nnetworks [7]. We look forward to others using and extending\nmobile-env for their research and welcome their contributions!\nACKNOWLEDGMENTS\nThis work has received funding from the German Research\nFoundation (DFG) within the Collaborative Research Center\n“On-The-Fly Computing” (SFB 901) and the open6GLab\n(German BMBF funding; grant 16KISK011).\nREFERENCES\n[1] N. C. Luong, D. T. Hoang, S. Gong, D. Niyato, P. Wang, Y .-C.\nLiang, and D. I. Kim, “Applications of deep reinforcement learning\nin communications and networking: A survey,” IEEE Communications\nSurveys & Tutorials, vol. 21, no. 4, pp. 3133–3174, 2019.\n[2] S. Schneider, A. Manzoor, H. Qarawlus, R. Schellenberg, H. Karl,\nR. Khalili, and A. Hecker, “Self-driving network and service coordi-\nnation using deep reinforcement learning,” in International Conference\non Network and Service Management (CNSM). IEEE, 2020, pp. 1–9.\n[3] W. Liu, L. Wang, E. Wang, Y . Yang, D. Zeghlache, and D. Zhang, “Rein-\nforcement learning-based cell selection in sparse mobile crowdsensing,”\nComputer Networks, vol. 161, pp. 102–114, 2019.\n[4] S. Vimal, M. Khari, N. Dey, R. G. Crespo, and Y . H. Robinson,\n“Enhanced resource allocation in mobile edge computing using re-\ninforcement learnin',
#  'g based MOACO algorithm for IIOT,” Computer\nCommunications, vol. 151, pp. 355–364, 2020.\n[5] Y . S. Nasir and D. Guo, “Multi-agent deep reinforcement learning\nfor dynamic power allocation in wireless networks,” IEEE Journal on\nSelected Areas in Communications, vol. 37, no. 10, 2019.\n[6] G. Brockman, V . Cheung, L. Pettersson, J. Schneider, J. Schul-\nman, J. Tang, and W. Zaremba, “OpenAI Gym,” arXiv preprint\narXiv:1606.01540, 2016.\n[7] S. Schneider and S. Werner, “ mobile-env GitHub repository,” https://\ngithub.com/stefanbschneider/mobile-env, 2021.\n[8] D. Brunori, S. Colonnese, F. Cuomo, and L. Iocchi, “A reinforcement\nlearning environment for multi-service UA V-enabled wireless systems,”\nin IEEE PerCom Workshops. IEEE, 2021, pp. 251–256.\n[9] Leurent, “highway-env,” https://github.com/eleurent/highway-env, 2018.\n[10] T. R. Henderson, M. Lacage, G. F. Riley, C. Dowell, and J. Kopena,\n“Network simulations with the ns-3 simulator,” SIGCOMM Demonstra-\ntion, vol. 14, no. 14, p. 527, 2008.\n[11] OpenSim, “OMNeT++ website,” https://omnetpp.org/, 2021.\n[12] A. Medeisis and A. Kajackas, “On the use of the universal okumura-\nhata propagation prediction model in rural areas,” in IEEE Vehicular\nTechnology Conference (VTC), vol. 3. IEEE, 2000, pp. 1815–1818.\n[13] J. Yoon, M. Liu, and B. Noble, “Random waypoint considered harm-\nful,” in IEEE International Conference on Computer Communications\n(INFOCOM). IEEE, 2003, pp. 1312–1321.\n[14] E. Liang, R. Liaw, R. Nishihara, P. Moritz, R. Fox, K. Goldberg, J. Gon-\nzalez, M. Jordan, and I. Stoica, “RLlib: Abstractions for distributed rein-\nforcement learning,” in International Conference on Machine Learning\n(ICML). PMLR, 2018, pp. 3053–3062.\n[15] P. Gawłowicz and A. Zubow, “ns-3 meets OpenAI Gym: The playground\nfor machine learning in networking research,” in ACM International\nConference on Modeling, Analysis and Simulation of Wireless and\nMobile Systems (MSWiM). ACM, 2019.\n1Interactive Jupyter notebook: https://bit.ly/3FDHKEk (Jan. 18, 202']

# %%
question = "What are benefits of mobile-env over other simulators?"

# tuner007/t5_abs_qa
for text_part in text_parts:
    print(get_answer_tuner(question, text_part))
# Only outputs one proper answer. Nice!
# Out:
# <pad> No answer available in context</s>
# <pad> No answer available in context</s>
# <pad> No answer available in context</s>
# <pad> No answer available in context</s>
# <pad> No answer available in context</s>
# <pad> No answer available in context</s>
# <pad> It is more flexible and more flexible than other simulators.</s>
# <pad> No answer available in context</s>
# <pad> No answer available in context</s>

# %%
# consciousAI/question-answering-generative-t5-v1-base-s-q-c
for text_part in text_parts:
    print(get_answer_consciousai(question, text_part))
# Out:
# [{'generated_text': 'many configuration options and is easy to extend'}]
# [{'generated_text': 'facilitating their evaluation and comparison'}]
# [{'generated_text': 'provide a useful tool for prototyping, training, and comparing existing approaches'}]
# [{'generated_text': 'enabling easy adoption and fast prototyping of new approaches'}]
# [{'generated_text': 'can be replaced by the agent’s actions'}]
# [{'generated_text': 'fast and simple training and evaluation'}]
# [{'generated_text': 'far more features'}]
# [{'generated_text': 'Enhanced resource allocation in mobile edge computing using re- inforcement learnin'}]
# [{'generated_text': 'Multi-agent deep reinforcement learning for dynamic power allocation in wireless networks'}]

# %%
# MaRiOrOsSi/t5-base-finetuned-question-answering
for text_part in text_parts:
    print(get_answer_mario(question, text_part))
# Out:
# It provides sensible default values and can be used out of the box.
# It is lightweight and fast.
# It provides a useful tool for prototyping and other control algorithms.
# It is simple and lightweight with sensible default values and predefined example scenarios.
# It provides a single-agent user interface.
# It allows users to simulate complex scenarios.
# It is more flexible, better documented, and licensed by the standard MIT license.
# It provides an open and simple yet flexible platform for reinforcement learning.
# It provides a more robust network than a traditional s simulation.

# %% [markdown]
# #### Build scoring function to find the best answer
#
# For extractive Q&A, HuggingFace seems to provide a scoring function within the standard pipeline.
# This score multiplies the probability of the stand and end index returned by the model.
#
# https://discuss.huggingface.co/t/how-to-find-confidence-score-in-qa-model-in-the-pipeline-module/5210
#
# For generative Q&A, models output variable-size sequences.
# Multiplying the probabilities of each output token would lead to lower scores for longer sequences, even if they are useful answers.
# I'll try averaging the token probabilities instead.
#
# To output the token probabilities, I have to configure the models and generate function accordingly.
# As an example, I'll use the MaRiOrOsSi/t5-base-finetuned-question-answering model, which provided the best answers.

# %%
# Tokenizer and Model were already loaded above; just reuse them here
from transformers.generation import GenerateEncoderDecoderOutput

question = "What is Valhalla?"
context = "In Norse mythology, Valhalla is a majestic, enormous hall located in Asgard, ruled over by the god Odin."
input = f"question: {question} context: {context}"

encoded_input = tokenizer_mario([input], return_tensors='pt')
# Can get scores per token if I output a GenerateEncoderDecoderOutput with return_dict_in_generate=True, output_scores=True
output: GenerateEncoderDecoderOutput = model_mario.generate(input_ids=encoded_input.input_ids, attention_mask=encoded_input.attention_mask, return_dict_in_generate=True, output_scores=True)
output
# Out:
# From v4.47 onwards, when a model cache is to be returned, `generate` will return a `Cache` instance instead by default (as opposed to the legacy tuple of tuples format). If you want to keep returning the legacy format, please set `return_legacy_cache=True`.
# GenerateEncoderDecoderOutput(sequences=tensor([[    0,    71, 25941,     6, 10933,  6358,     1]]), scores=(tensor([[-46.9212, -10.5379, -27.4036,  ..., -87.9269, -87.4440, -87.6389]]), tensor([[-30.3731, -12.4038, -24.3930,  ..., -63.0842, -62.7218, -62.9792]]), tensor([[-38.2012, -19.0661, -24.7387,  ..., -80.1341, -79.5276, -79.6145]]), tensor([[-40.1083, -22.2432, -36.1136,  ..., -82.0332, -81.5725, -81.9746]]), tensor([[-44.6734, -20.0176, -34.0707,  ..., -89.7348, -89.2161, -89.3545]]), tensor([[-40.1629,   1.0713, -21.6641,  ..., -72.6069, -72.4596, -72.4369]])), logits=None, encoder_attentions=None, encoder_hidden_states=None, decoder_attentions=None, cross_attentions=None, decoder_hidden_states=None, past_key_values=((tensor([[[[ 4.5368e-01,  2.8157e-01, -1.6857e-01,  ..., -3.2498e-01,
#             2.2168e-01, -1.8275e-01],
#           [-6.5928e-01,  1.9843e+00, -1.4105e+00,  ...,  2.5199e-01,
#             1.0230e+00,  3.0545e-01],
#           [ 1.0918e+00,  5.2156e-01,  1.0391e-02,  ...,  1.5754e+00,
#            -6.0870e-01, -2.5155e-01],
#           [ 5.6278e-01,  2.7920e-01,  1.9450e-01,  ..., -6.4482e-01,
#            -1.0553e-01, -9.4458e-01],
#           [-0.8478, -0.9833,  1.9018,  ...,  0.7064, -1.2266, -0.6850],
#           ...,
#           [-0.3258,  1.4380,  1.0604,  ...,  0.5176, -0.9526,  2.5897],
#           [ 1.3866,  1.0423,  2.7606,  ..., -1.7237, -0.4532,  2.0644],
#           [ 0.7220,  0.2931,  0.2675,  ...,  0.0375,  0.1302, -0.0688]],
#
#          [[ 1.6436, -0.9554,  0.0522,  ..., -3.4516,  0.3264,  1.9239],
#           [ 1.0384, -0.8052,  0.3445,  ..., -3.6617, -0.1881,  2.1347],
#           [ 1.1760, -0.3261,  0.3579,  ..., -3.4360,  0.1245,  1.6285],
#           ...,
#           [ 5.0113, -0.6112, -1.1976,  ...,  1.1359, -0.6686, -2.9888],
#           [ 1.1301, -0.5379, -0.5453,  ..., -1.1192,  2.7070, -0.4083],
#           [ 0.5628, -0.1090, -0.3090,  ..., -0.6185,  0.9501, -0.5790]],
#
#          [[ 0.9857,  1.5127,  1.4307,  ..., -0.6661,  1.2887, -0.3858],
#           [ 1.0845,  1.5961,  2.1806,  ..., -0.0254,  0.8965, -0.9297],
#           [ 1.0740, -0.8892,  0.9799,  ...,  0.5401,  0.6949, -0.7794],
#           ...,
#           [-1.4788, -2.7550,  0.7451,  ..., -0.2169, -3.7035, -2.2566],
#           [ 0.2759,  2.0436, -0.4950,  ...,  0.1102, -0.8972, -1.8368],
#           [-0.1145, -0.5400,  0.3554,  ..., -0.1056, -0.2011,  0.1590]],
#
#          ...,
#
#          [[ 1.5773, -1.4259,  1.2359,  ..., -0.0405,  1.7530,  1.3700],
#           [ 1.3778, -1.8611,  1.0628,  ..., -0.1578,  2.0753,  1.3179],
#           [-0.0640, -0.0570,  2.3331,  ..., -0.8435,  3.9007,  1.4578],
#           ...,
#           [-2.2355,  4.2237,  2.5933,  ...,  0.7254, -1.3586,  2.8456],
#           [-0.2448,  1.4007, -0.1790,  ...,  0.3859, -0.8377,  0.5850],
#           [ 0.4496,  1.0103, -0.5831,  ...,  1.6100, -0.2894,  0.2175]],
#
#          [[-1.8255,  0.2703,  1.6687,  ...,  2.1812, -1.0178, -0.8867],
#           [-2.1709,  0.6138,  1.5507,  ...,  2.2570, -1.7090, -0.3542],
#           [-1.9459,  1.1285, -0.9865,  ...,  2.5557, -2.4860,  0.5035],
#           ...,
#           [ 0.8899, -0.1236,  4.7701,  ...,  3.4796,  0.9417, -0.1879],
#           [-1.1030,  0.9217,  1.4089,  ...,  0.7104, -0.3446, -0.2447],
#           [ 0.2439, -0.0482,  0.9240,  ..., -0.5256,  0.6534, -0.2215]],
#
#          [[ 0.6901,  0.3702, -2.8489,  ..., -0.9424, -0.5084, -0.1861],
#           [ 0.9968,  0.0281, -3.0425,  ..., -1.4214, -0.4971, -1.0276],
#           [ 2.4009,  0.2314, -2.7304,  ..., -3.3815, -2.1986, -0.9999],
#           ...,
#           [-0.7472,  3.9624,  0.2648,  ...,  3.4728,  0.2709,  2.2822],
#           [-6.8186e-01, -1.4586e+00,  2.5932e-01,  ...,  7.0471e-01,
#            -5.3726e-01, -1.1839e-01],
#           [ 8.3814e-01,  2.8376e-01,  1.7421e+00,  ..., -5.8070e-01,
#            -1.3077e-01, -5.5350e-01],
#           [-1.2669e-01,  3.8470e-01,  6.7195e-01,  ..., -2.5322e-02,
#             2.0120e-01,  8.6655e-01],
#           [ 5.3136e-01,  9.9358e-02,  7.7565e-01,  ..., -2.4245e-01,
#            -2.8360e-01, -3.2440e-01],
#           [-1.8001e+00, -7.2495e-01,  1.2005e+00,  ..., -2.4631e-01,
#            -9.0897e-01, -6.6490e-01]],
#
#          [[-1.6822e-01,  1.3296e-01, -1.3428e-01,  ...,  2.2574e+00,
#            -2.0133e-01, -3.8725e-01],
#           [-1.2333e+00, -4.0357e-01, -1.1631e+00,  ..., -1.6808e+00,
#            -1.9341e-01,  2.3073e-01],
#           [-1.5833e-01,  5.0928e-01, -4.1390e-01,  ..., -2.3662e+00,
#             3.1353e-01, -1.1428e+00],
#           [-8.2211e-01,  2.3873e-01, -6.4225e-01,  ..., -1.7222e+00,
#            -2.8017e-01, -1.2703e+00],
#           [ 3.1232e-02,  5.7343e-01, -3.0793e-01,  ..., -2.1924e+00,
#             1.9879e-01, -1.0563e+00],
#           [ 1.8593e-01, -1.4909e-01,  3.1995e-01,  ..., -1.6972e+00,
#             6.3470e-01, -1.1216e+00]],
#
#          [[-2.2586e-02,  1.2752e-01,  1.2100e-01,  ..., -1.5412e-01,
#            -1.8368e-01, -2.5705e-01],
#           [-9.7482e-01,  7.3928e-01,  2.9668e-01,  ..., -1.4630e+00,
#             4.5478e-01,  3.0463e-01],
#           [-4.2234e-01, -5.5018e-01, -1.1537e-01,  ..., -3.6064e-01,
#            -1.4445e+00, -2.9749e-01],
#           [ 4.5604e-01, -4.4500e-01, -1.4920e-01,  ..., -3.1527e-01,
#            -5.8212e-01,  5.5780e-01],
#           [ 2.1519e-01, -9.3973e-02, -2.1639e-01,  ..., -9.6341e-02,
#            -2.0916e+00,  5.1576e-01],
#           [-1.2742e-01, -9.1874e-01,  2.4608e-01,  ..., -1.1253e+00,
#             2.0646e-01, -7.9973e-01]],
#
#          ...,
#
#          [[ 1.1906e-01,  3.5057e-01, -1.1435e-02,  ...,  2.4214e-02,
#             2.1760e-01,  2.0463e-01],
#           [-4.2562e-02,  1.5080e+00, -1.0914e+00,  ...,  6.4703e-02,
#             4.0155e-01,  1.3336e+00],
#           [ 1.1247e+00,  2.9106e-01, -2.5227e-01,  ..., -2.2463e-01,
#             9.2032e-01,  8.3872e-01],
#           [-2.2477e-01,  6.4670e-01, -2.4468e-02,  ..., -1.0382e-01,
#             7.7205e-01,  2.6265e-01],
#           [ 2.2250e-01,  2.8035e-02,  2.0676e-02,  ...,  1.2934e-01,
#             1.4397e+00,  1.0982e+00],
#           [-6.7548e-01, -5.2742e-01,  1.1407e-01,  ...,  1.1896e+00,
#             5.0340e-01, -2.3307e-01]],
#
#          [[ 1.4906e-01,  7.1192e-02,  3.5868e-01,  ..., -1.1954e-01,
#             9.0435e-02,  2.8378e-01],
#           [-9.6900e-01,  5.5295e-01, -5.6006e-01,  ..., -2.2790e-01,
#             7.2439e-01, -1.1809e+00],
#           [ 4.0077e-01, -7.7109e-01,  1.9984e+00,  ...,  4.1571e-02,
#            -7.9425e-01,  1.2729e+00],
#           [-5.9887e-01, -4.8458e-02, -6.3871e-01,  ..., -7.7627e-01,
#            -7.1992e-01, -4.6321e-01],
#           [-5.7952e-01, -1.0499e+00, -2.9383e-01,  ..., -3.5578e-01,
#            -2.6224e-01,  6.3952e-01],
#           [ 1.9169e-04,  4.8083e-01,  1.8059e+00,  ..., -1.6163e-01,
#            -4.9677e-01,  4.2951e-01]],
#
#          [[ 2.1176e-02,  3.6510e-01,  2.7811e-01,  ...,  1.6473e-01,
#            -2.1195e+00, -3.4976e-01],
#           [-4.7316e-01,  5.8890e-02,  6.2818e-01,  ...,  9.0263e-01,
#             1.8410e+00,  1.3096e-01],
#           [-9.7926e-01, -4.1891e-01, -1.0141e-01,  ...,  9.1309e-01,
#            -1.4988e-01, -6.2744e-02],
#           [ 9.2435e-01, -4.3341e-01, -6.9160e-01,  ...,  2.9225e-01,
#             2.1928e+00,  7.4037e-01],
#           [ 8.2682e-01,  1.4109e-01,  8.0199e-01,  ..., -8.0509e-01,
#             6.5478e-01, -1.8228e-01],
#           [-4.1550e-01, -1.2928e+00,  3.1254e-02,  ..., -1.5225e-01,
#             2.3289e+00, -6.3553e-01]]]]), tensor([[[[-5.1119e-03, -5.0845e-02, -1.7764e-02,  ..., -5.4426e-02,
#             1.6768e-01, -4.3023e-01],
#           [ 9.0664e-01,  9.2628e-01,  1.8732e+00,  ...,  1.0630e+00,
#             1.6073e+00,  1.2497e+00],
#           [-1.7929e+00, -1.2153e+00, -1.0531e+00,  ...,  4.2183e+00,
#             2.0964e+00,  7.8489e-01],
#           [ 7.8622e-01, -3.1430e-01, -4.7472e-01,  ...,  1.5203e+00,
#            -1.0372e+00,  2.3896e+00],
#           [-5.6325e-01,  3.0791e-01, -1.7452e+00,  ...,  3.2990e+00,
#             5.8834e-01,  2.4010e+00],
#           [ 4.3955e-01, -2.0381e-01,  2.2356e-01,  ...,  2.5698e-01,
#             2.9027e-01,  2.9380e+00]],
#
#          [[-3.7827e-02,  1.2152e-01,  1.4403e-02,  ...,  3.6748e-02,
#             2.1016e-02,  1.2435e-02],
#           [ 4.3422e-01, -2.3255e+00,  1.0488e+00,  ..., -6.0247e-02,
#            -3.2035e+00,  5.2077e-01],
#           [-1.0213e+00,  4.4480e-02,  8.2480e-01,  ...,  1.0927e+00,
#             1.7641e-01, -9.9991e-01],
#           [-3.2045e-01, -1.6315e+00,  4.9245e-01,  ..., -2.9580e+00,
#             8.2057e-01,  6.2224e-01],
#           [ 8.8575e-01, -6.2374e-01,  2.1064e+00,  ..., -4.8926e-01,
#            -1.2076e+00, -2.1083e-01],
#           [ 6.2031e-01,  2.2987e+00, -1.3437e+00,  ..., -7.6399e-02,
#             2.2517e+00,  5.5899e-01]],
#
#          [[-2.5773e-01, -2.9952e-02, -1.0683e-02,  ..., -5.8683e-02,
#             1.4654e-01, -5.4346e-02],
#           [ 1.1335e+00, -3.1928e-01, -1.9258e+00,  ...,  1.5043e+00,
#             1.0188e+00, -2.2561e+00],
#           [ 1.6525e+00,  2.6501e+00, -1.5515e+00,  ..., -1.1145e+00,
#            -4.3475e-01,  1.5581e+00],
#           [ 3.9564e-01, -4.8541e-01, -2.7820e+00,  ..., -6.2727e-01,
#            -5.3427e-01,  9.8601e-01],
#           [-1.5590e+00,  4.7567e+00, -3.1726e+00,  ..., -1.3450e+00,
#            -6.0907e-01, -5.2872e-01],
#           [-2.8106e+00,  7.3448e-01,  1.9264e+00,  ..., -4.2114e-01,
#            -1.7777e+00,  1.2785e+00]],
#
#          ...,
#
#          [[-2.3068e-01,  3.2913e-02, -2.3562e-02,  ..., -3.9057e-01,
#             2.4817e-01, -2.1791e-01],
#           [ 2.5754e-01,  1.4614e+00, -1.9531e+00,  ..., -2.3766e-01,
#             1.7324e-01,  3.1120e-01],
#           [ 4.4796e+00, -4.1935e+00,  1.0450e-02,  ...,  1.2522e+00,
#            -2.9703e-01,  1.5300e+00],
#           [ 9.4411e-01,  1.6112e+00,  7.4606e-01,  ...,  1.0589e+00,
#            -2.1090e+00, -1.5002e+00],
#           [ 4.3117e+00,  1.4329e+00,  2.6860e+00,  ...,  8.1867e-01,
#            -2.1726e+00, -2.0493e-01],
#           [ 2.2721e+00,  3.1309e-01, -8.2131e-01,  ..., -5.3351e-01,
#             6.4938e-01,  2.1386e+00]],
#
#          [[ 4.7384e-02,  3.6719e-02, -3.3244e-03,  ...,  1.4674e-01,
#            -3.6333e-02,  9.8650e-02],
#           [ 7.0932e-02, -4.5156e-02, -8.8779e-01,  ...,  3.5107e-01,
#             2.1947e-02, -1.2344e+00],
#           [-1.0740e+00, -4.4575e-01,  6.9491e-01,  ...,  9.7535e-01,
#             6.3238e-01, -1.5988e+00],
#           [ 3.4644e-01, -5.1577e-01,  5.2550e-01,  ...,  4.2670e-01,
#             4.8612e-01, -1.7770e+00],
#           [ 6.6045e-01,  1.7056e+00, -9.1181e-01,  ...,  5.3317e-01,
#            -1.1618e+00, -2.2423e+00],
#           [-1.5817e+00,  1.8980e+00, -2.2754e-01,  ...,  2.6909e+00,
#            -2.7548e-01,  1.1769e+00]],
#
#          [[ 1.0541e-01, -1.2185e-01,  3.3060e-02,  ..., -1.1981e-01,
#             1.3378e-02, -1.3508e-01],
#           [-1.9734e+00,  1.2134e+00,  2.1782e+00,  ...,  8.9455e-01,
#            -2.4604e-01, -9.8345e-01],
#           [-9.4708e-02,  8.5703e-01, -1.3342e+00,  ...,  4.3175e-01,
#            -2.0762e+00,  7.4247e-01],
#           [ 9.1332e-01,  2.2838e+00,  1.5113e+00,  ...,  1.2258e-03,
#             5.7262e-01, -6.4675e-01],
#           [ 1.5637e+00,  1.0786e+00, -2.4418e+00,  ..., -7.6288e-01,
#           [ 6.9250e-01,  3.3915e+00, -1.8990e+00,  ..., -7.3133e-01,
#             6.6801e-01,  2.9595e-01],
#           [ 1.9982e+00, -2.3667e+00,  1.5074e+00,  ...,  8.1938e-01,
#            -1.4057e+00, -1.2230e-01],
#           [-5.0354e-01,  2.0493e-01, -2.2645e-01,  ..., -2.7031e-01,
#             3.9990e-01,  1.8709e-01]],
#
#          [[-5.5542e-01,  1.7116e+00, -3.5023e-01,  ...,  5.7990e-01,
#             1.5375e+00, -8.2494e-01],
#           [-1.8534e-01,  7.8229e-01, -2.0387e-01,  ...,  4.8386e-01,
#             7.3854e-01, -8.4596e-01],
#           [ 3.2359e-01, -7.7443e-01,  9.9671e-01,  ...,  3.8344e-02,
#             2.0625e+00,  9.5277e-01],
#           ...,
#           [-3.7957e+00,  4.6827e+00, -6.3133e-01,  ..., -7.9833e-01,
#            -5.8569e-02, -1.9333e+00],
#           [-3.1730e-01,  2.1542e+00,  3.2985e-01,  ..., -7.5609e-01,
#             2.6360e+00,  1.6696e+00],
#           [-6.9053e-02,  6.3047e-01,  3.9992e-01,  ...,  4.7743e-01,
#             7.2989e-02,  6.6105e-01]],
#
#          [[ 7.9400e-01,  3.0487e+00, -1.6552e+00,  ...,  2.1513e+00,
#            -2.5168e+00,  2.5873e+00],
#           [ 1.3076e+00,  3.1044e+00, -1.1977e+00,  ...,  2.0694e+00,
#            -1.9495e+00,  1.8783e+00],
#           [ 1.0774e+00,  3.1876e+00, -3.0357e+00,  ...,  3.3456e+00,
#            -3.7053e+00, -1.5497e+00],
#           ...,
#           [-5.9176e+00, -2.3875e+00,  7.1505e-01,  ...,  1.6456e+00,
#             9.0571e-01,  4.4851e+00],
#           [-7.6932e-01, -6.8042e-02, -2.8218e+00,  ...,  7.6005e-01,
#            -1.5466e+00,  5.3638e-01],
#           [ 6.8626e-01, -9.8603e-01, -8.6661e-01,  ...,  1.1264e-01,
#             2.6967e-01, -9.6049e-01]]]]), tensor([[[[ 2.5065e+00,  5.9028e+00, -3.2949e+00,  ...,  2.5228e+00,
#             5.4430e+00,  2.9160e+00],
#           [ 2.9780e+00,  4.9370e+00, -4.2862e+00,  ...,  2.0834e+00,
#             4.4172e+00,  3.6987e+00],
#           [ 3.4729e+00,  2.4040e+00, -3.8671e+00,  ...,  8.1338e-01,
#             1.8227e+00,  2.1969e+00],
#           ...,
#           [-2.5594e+00,  2.0163e+00,  1.5859e+00,  ..., -6.8069e-02,
#             5.6141e+00, -5.7260e+00],
#           [-6.8311e-01,  1.4134e+00,  3.3275e+00,  ..., -2.3464e+00,
#            -3.2590e-01,  1.8036e+00],
#           [ 3.8687e-01,  5.2744e-02,  1.6485e-01,  ...,  1.6547e-01,
#             5.3027e-03,  4.2488e-01]],
#
#          [[-3.7477e+00,  1.0857e+00, -8.3701e-01,  ...,  1.3898e-01,
#            -2.0961e+00,  3.0935e+00],
#           [-2.5758e+00,  1.6835e+00, -9.5978e-01,  ..., -4.2976e-01,
#            -2.6395e+00,  2.7356e+00],
#           [-1.9148e+00,  3.0995e+00,  9.2362e-01,  ..., -1.8424e+00,
#            -4.7146e+00,  1.1835e+00],
#           ...,
#           [-8.0169e-01,  1.6393e-02, -1.5365e+00,  ..., -3.2602e+00,
#            -2.1285e+00, -1.2416e+00],
#           [ 2.9426e+00,  4.5602e+00,  1.6099e+00,  ..., -3.4714e+00,
#            -2.4463e+00, -4.9309e-01],
#           [-7.5636e-02, -1.4967e-01, -4.0216e-01,  ...,  2.5813e-01,
#             3.9043e-01,  2.5943e-01]],
#
#          [[ 1.4798e-01,  3.1140e+00,  3.9831e-01,  ...,  3.0891e+00,
#            -4.8393e+00,  3.8211e-01],
#           [-9.3052e-01,  3.3598e+00,  8.1857e-01,  ...,  3.7404e+00,
#            -5.1013e+00,  1.4599e+00],
#           [ 3.6810e+00,  2.7528e+00, -1.0724e+00,  ...,  3.1372e+00,
#            -5.4025e+00,  1.9004e+00],
#           ...,
#           [-4.7174e-01, -4.7630e-02,  1.0933e-02,  ..., -3.0266e+00,
#             6.1872e+00,  1.4856e+00],
#           [-1.1243e+00,  1.2143e+00,  9.5030e-01,  ...,  1.3828e+00,
#            -4.0914e-01,  4.3359e-01],
#           [-5.2225e-01, -1.7264e-01, -6.7832e-02,  ...,  1.3213e-01,
#             2.7567e-01, -1.4067e-02]],
#
#          ...,
#
#          [[-1.9446e+00,  9.5489e-01, -1.5670e+00,  ..., -2.9195e+00,
#             1.4552e+00,  1.0260e+00],
#           [-2.0282e+00, -6.0636e-02, -2.5051e+00,  ..., -2.8892e+00,
#             2.4902e+00,  3.8234e-01],
#           [-1.7603e+00, -3.5382e+00, -3.4643e+00,  ..., -1.9783e+00,
#            -1.0471e-01,  6.1412e-01],
#           ...,
#           [ 9.8790e-01,  5.2047e+00,  3.1412e+00,  ..., -3.0007e+00,
#            -1.0181e+00,  9.8684e-01],
#           [-9.5537e-02, -3.0276e-02,  1.3555e+00,  ...,  1.3327e+00,
#            -1.6512e+00, -6.8247e-01],
#           [ 4.8949e-01, -5.1844e-01, -4.0083e-01,  ...,  1.7942e-01,
#             6.7985e-02,  3.4994e-01]],
#
#          [[ 9.5390e-01,  1.4766e+00,  2.5160e+00,  ..., -1.5342e+00,
#            -1.8179e+00,  2.5272e-01],
#           [-3.9371e-01,  7.6373e-01,  3.2468e+00,  ..., -1.1468e+00,
#            -1.7091e+00,  5.1328e-01],
#           [-1.5247e+00, -5.4645e-01,  3.7701e+00,  ..., -1.0941e+00,
#            -1.4907e+00,  5.6655e-01],
#           ...,
#           [ 3.6541e+00, -1.9836e-01, -3.5930e+00,  ..., -1.2491e+00,
#             4.2640e+00,  3.2189e+00],
#           [ 1.2965e+00,  2.2996e+00,  3.7143e+00,  ..., -1.7513e-01,
#            -4.2409e+00, -2.6350e+00],
#           [ 4.6607e-01,  3.1506e-01,  7.1065e-01,  ..., -2.4509e-01,
#            -1.3559e-01, -1.0267e-01]],
#
#          [[ 2.4425e+00,  2.6921e+00,  1.3386e-01,  ...,  3.0001e-01,
#            -2.4192e+00,  2.7010e+00],
#           [ 1.6577e+00,  2.1691e+00,  8.6859e-01,  ...,  5.9044e-01,
#            -1.9306e+00,  2.2967e+00],
#           [ 1.0239e+00,  3.1707e-01, -7.2346e-01,  ...,  5.2607e-01,
#            -6.3733e-01,  2.3216e+00],
#           ...,
#           [ 5.3817e+00, -1.1743e-01, -3.8659e+00,  ...,  9.8543e-01,
#            -2.2200e-01, -9.1698e-01],
#           [ 5.5597e-01,  5.0394e-01, -1.5089e+00,  ...,  2.8107e-01,
#             1.2051e+00,  1.6174e+00],
#           [ 5.9343e-01,  1.4326e-01,  3.4244e-01,  ..., -7.5275e-01,
#             1.7294e-01, -1.2906e-01]]]])), (tensor([[[[ 0.2925, -0.1948, -0.2992,  ...,  0.0805, -0.1846,  0.2139],
#           [ 0.4088, -0.3339, -0.9662,  ..., -0.3410, -1.1022, -0.7856],
#           [ 0.6385,  0.6262, -0.6316,  ...,  0.0460, -0.6683,  1.1554],
#           [ 0.0134,  0.2985, -0.2880,  ..., -0.1081, -0.3380,  0.3718],
#           [-0.3786,  0.0239, -0.8196,  ...,  0.1136, -0.2249,  0.2354],
#           [ 0.3416,  0.1552, -0.7753,  ..., -0.3611, -0.4548, -0.9126]],
#
#          [[ 0.2494,  0.0386, -0.0516,  ...,  0.0643, -0.0191,  0.2773],
#           [ 1.5454, -0.5280, -0.6486,  ...,  0.4444, -0.7282, -0.7997],
#           [-0.4849,  0.0939,  0.3793,  ..., -0.1481, -0.6518, -0.4955],
#           [-0.9121, -1.3106,  0.2920,  ...,  0.0916,  0.5449, -0.0169],
#           [-0.9561, -0.5900, -0.9914,  ..., -0.6663,  1.3887, -1.1004],
#           [-0.4173,  0.0162,  0.5732,  ..., -0.1603, -0.1280, -1.9397]],
#
#          [[ 0.2397,  0.0266, -0.0544,  ..., -0.2714, -0.1026, -0.0483],
#           [ 0.8331,  0.4843,  0.8849,  ...,  0.8134, -0.2197, -1.5970],
#           [ 0.9206, -0.6779, -0.4540,  ...,  0.5023,  0.2535, -1.6744],
# ...
#
#          [[ 1.1499e+00,  5.4384e+00,  3.2788e+00,  ...,  2.3589e+00,
#            -2.7329e-01, -7.2469e+00],
#           [ 3.1804e+00,  7.4210e+00,  3.9268e+00,  ...,  1.2720e+00,
#            -9.5796e-01, -4.6322e+00],
#           [-3.3293e+00,  4.3472e+00,  7.4428e+00,  ...,  4.3397e+00,
#             2.9421e+00,  3.2495e+00],
#           ...,
#           [-7.4579e+00,  1.0180e+00,  1.0169e+01,  ..., -1.8543e+00,
#             4.6193e-01,  1.5134e+01],
#           [-6.0721e+00, -2.6715e+00, -3.8796e+00,  ..., -6.3930e+00,
#             8.2365e-01,  5.7580e+00],
#           [-5.7145e-02,  6.7977e-01, -2.3804e-01,  ...,  1.5174e-01,
#             1.5372e-02,  4.6351e-01]],
#
#          [[-1.4721e+00,  1.6001e+00, -2.7883e+00,  ...,  1.1905e-01,
#             2.6297e+00, -1.2958e+00],
#           [ 5.0380e-02,  4.6985e+00, -1.0307e+00,  ..., -1.6628e+00,
#             2.3259e+00,  5.0494e-01],
#           [-1.3840e+00, -3.0913e-01,  1.5048e+00,  ..., -6.3867e-01,
#             6.0701e-01, -2.1415e-01],
#           ...,
#           [ 9.2992e+00, -9.4699e+00, -3.7145e+00,  ..., -9.1101e+00,
#            -2.7293e+00,  1.5693e+00],
#           [-1.5519e+00,  8.5498e-01, -9.9487e+00,  ..., -5.4936e+00,
#             6.2267e+00,  3.8115e+00],
#           [-1.2827e-01, -3.0370e-01, -1.1481e-01,  ...,  4.6290e-01,
#             5.8153e-01, -6.2295e-01]]]])), (tensor([[[[-5.5124e-01, -2.8278e-01, -9.3831e-01,  ...,  1.3911e+00,
#             9.6316e-01,  1.8207e-01],
#           [-6.2375e-01,  1.0592e+00, -3.4214e-01,  ...,  1.5622e+00,
#             9.7472e-01,  4.8683e-01],
#           [-9.6628e-01, -5.2286e-01, -6.6055e-01,  ..., -3.8540e-01,
#             2.9193e+00, -5.3492e-01],
#           [ 9.5100e-01,  2.8456e-01,  4.0807e-01,  ..., -3.2765e-04,
#             2.3751e+00,  4.4081e-01],
#           [-4.0008e-01, -1.2716e-01, -2.3096e-01,  ..., -7.9916e-02,
#             2.4982e+00, -5.0366e-01],
#           [-5.8771e-01,  1.2526e+00, -6.4568e-01,  ...,  7.7210e-01,
#             1.3335e+00,  1.8124e-01]],
#
#          [[ 3.6046e-01, -8.0127e-02, -1.4080e+00,  ..., -5.4822e-01,
#             7.4274e-01,  2.3401e-01],
#           [ 6.4910e-01,  1.0187e+00,  1.7772e-01,  ..., -7.5221e-01,
#             8.6326e-02, -5.6507e-02],
#           [ 2.0685e-01,  2.2442e-01, -1.0864e+00,  ...,  6.9355e-01,
#             5.5358e-01,  6.3783e-01],
#           [-1.4071e+00,  1.5889e+00, -2.7637e-01,  ..., -1.4039e+00,
#             3.3723e-01, -3.1263e-01],
#           [ 1.5961e-01, -1.9334e-03, -6.3045e-01,  ...,  5.2880e-01,
#            -6.0094e-01,  1.7606e+00],
#           [-7.0306e-01,  6.0073e-01, -2.0445e+00,  ..., -5.1519e-01,
#             1.9630e+00,  4.8666e-01]],
#
#          [[-3.0712e-01,  2.2404e-01, -5.9587e-01,  ...,  2.4775e-01,
#            -1.5497e-01, -2.3987e-01],
#           [ 2.1176e-01,  4.1266e-01, -9.8085e-01,  ...,  1.2589e+00,
#            -2.2255e-01, -2.9050e+00],
#           [-9.0150e-02, -7.6664e-01, -1.1105e-01,  ..., -4.8114e-01,
#            -3.9638e-01, -2.5726e+00],
#           [-1.5096e+00, -3.9820e-02,  5.3639e-01,  ...,  1.0117e+00,
#            -1.3635e+00, -3.3923e+00],
#           [-1.9063e+00,  5.6248e-02, -6.2972e-01,  ..., -5.3156e-01,
#             1.0491e-01, -2.9523e+00],
#           [-5.0761e-01, -1.0001e+00, -4.3735e-01,  ..., -8.2050e-01,
#             6.4788e-01, -3.0364e+00]],
#
#          ...,
#
#          [[ 1.9441e+00, -8.8113e-01, -1.3580e+00,  ...,  3.3285e-01,
#             2.2852e+00, -8.2654e-01],
#           [ 5.2128e+00, -2.2617e+00, -1.3722e+00,  ...,  6.9983e-01,
#             2.4563e+00,  1.9081e-01],
#           [ 5.5205e+00, -1.1526e+00, -8.3992e-01,  ...,  3.7545e-01,
#             6.6395e-01, -1.6025e+00],
#           [ 6.2376e+00, -1.8037e-01, -4.2916e-01,  ...,  2.1350e-01,
#             4.2545e-01,  5.2223e-01],
#           [ 4.7855e+00, -3.3358e-01, -1.4956e+00,  ...,  2.5990e-01,
#            -4.7347e-01, -8.3637e-01],
#           [ 5.0381e+00,  2.7863e-01, -1.3316e+00,  ..., -1.1058e-01,
#             2.3333e+00,  2.8575e-01]],
#
#          [[ 3.5342e-01,  1.5341e-01,  5.8912e-01,  ..., -1.2638e+00,
#             3.3625e-01, -9.8074e-01],
#           [ 5.8459e-02, -3.8917e-02,  5.3962e-01,  ..., -1.1977e+00,
#             7.5646e-01, -2.7785e+00],
#           [ 8.5257e-01,  1.2646e+00,  1.4127e+00,  ..., -3.8100e-01,
#             1.1630e-01,  3.6907e-01],
#           [-6.1078e-01, -1.3333e-01,  2.3399e+00,  ..., -1.7466e+00,
#            -1.2016e-01, -1.0632e+00],
#           [ 4.1294e-01, -1.6230e-01,  1.3564e+00,  ...,  4.2996e-02,
#             1.5570e+00,  7.5800e-01],
#           [-1.4884e+00,  1.0642e+00,  1.0893e+00,  ..., -2.0345e-01,
#             2.0312e-01, -1.2676e-01]],
#
#          [[-6.2082e-01,  7.7468e-01, -2.5317e-01,  ..., -5.0840e-01,
#            -1.3389e+00,  9.7730e-01],
#           [-1.1982e+00,  2.2585e+00, -1.5526e+00,  ...,  4.6320e-01,
#            -7.0461e-01,  4.6904e-01],
#           [-3.6159e-01,  1.5519e+00, -7.4319e-01,  ..., -7.2070e-02,
#            -1.8775e+00,  9.8463e-01],
#           [-1.4261e+00,  1.9011e+00,  1.2708e+00,  ...,  5.8632e-02,
#            -2.1468e+00,  2.1810e+00],
#           [-1.4336e+00,  1.1573e+00,  2.6866e-01,  ..., -5.6814e-01,
#            -4.5092e-01,  9.6573e-01],
#           [-2.9859e-01,  1.5935e+00, -4.9900e-02,  ..., -1.0465e+00,
#            -1.3870e+00, -8.0689e-01]]]]), tensor([[[[  0.3865,   1.8592,  -2.0477,  ...,  -3.5376,   2.1386,  -1.7387],
#           [  6.5442,   5.7185,  -0.0906,  ...,  -7.7965,   3.9284,  -2.8005],
#           [  3.3702,   1.7704,  -3.5416,  ...,  -1.8430,   5.5411,   1.0486],
#           [ -3.7622,  -2.9268,   0.0879,  ...,  -6.7351,   7.1736,   1.7094],
#           [  4.5784,   2.4224,  -1.4223,  ...,  -0.1358,   4.4434,  -0.3104],
#           [ -0.0108,   0.5347,  -1.7888,  ...,   2.6659,   4.0997,  -1.4027]],
#
#          [[ -2.0043,   1.9837,  -0.0139,  ...,  -1.9011,   0.4872,  -1.1915],
#           [  1.6650,   0.8211,  -0.5854,  ...,  -2.4602,  -1.1300,  -0.3157],
#           [  1.5426,   2.2231,   0.5214,  ...,  -7.1144,  -1.8857,   2.4827],
#           [ -1.2144,  -0.8405,  -1.4711,  ...,  -8.2827,  -2.8262,   0.6780],
#           [ -1.5638,   4.8600,   0.6259,  ..., -10.1357,  -0.3540,  -0.2783],
#           [ -1.5063,   0.6394,  -1.2741,  ...,  -4.2272,   1.1240,  -0.4692]],
#
#          [[ -1.2580,  -3.2255,   1.3247,  ...,  -6.3557,   2.3543,  -2.6510],
#           [ -2.4032,  -4.7933,   1.9847,  ...,  -7.5521,   3.8956,  -0.7843],
#           [ -4.7206,  -0.7137,  -2.2068,  ...,  -4.2161,   6.5678,  -0.7887],
#           [ -3.4759,  -3.7233,  -0.9424,  ...,  -8.1881,   3.1211,  -0.3574],
#           [ -4.2249,  -5.7882,   1.2805,  ...,  -4.1535,   5.4833,   0.1997],
#           [ -1.4221,  -4.2315,  -1.2626,  ...,  -3.5265,   2.6289,   2.7287]],
#
#          ...,
#
#          [[ -3.2274,  -6.7204,  -4.1652,  ...,  -0.7510,  -0.4113,   0.8937],
#           [ -1.1806, -10.3938,  -4.8050,  ...,   0.7259,  -1.2602,  -1.5985],
#           [  0.3811,  -5.9426,  -2.7488,  ...,   0.8683,  -1.6995,   1.8600],
#           [  2.2161,  -4.4208,  -5.1697,  ...,   1.1465,  -2.2381,   1.9525],
#           [  2.1568,  -7.9716,  -7.0011,  ...,  -2.3085,   1.5575,  -1.9743],
#           [ -1.0117,  -4.8035,  -1.0738,  ...,   0.5286,  -0.7152,  -1.4412]],
#
#          [[  1.0438,   6.1922,  -1.0651,  ...,   0.2497,   1.9025,  -2.2749],
#           [ -1.4188,   7.5618,  -4.9948,  ...,   1.8001,   0.8072,  -4.7773],
#           [  1.5217,   4.9752,  -2.5942,  ...,   2.3155,  -1.8474,  -0.6490],
#           [  1.4511,   4.9918,  -9.3431,  ...,  -0.8384,  -3.1276,  -4.0858],
#           [  2.5335,   5.8802,   2.5009,  ...,   2.6022,   0.6340,  -3.9151],
#           [ -5.7586,   4.6706,  -5.0385,  ...,  -0.3062,   1.4289,  -1.8596]],
#
#          [[  0.1468,   0.8999,   2.2100,  ...,   0.5260,  -0.6394,   2.6516],
#           [  0.5502,   0.9740,   3.5954,  ...,   0.0554,   1.4228,   1.4903],
#           [  2.7509,  -1.0995,   2.6945,  ...,   4.5646,   1.1811,  -0.2093],
#           [  2.9976,   0.5369,   9.4887,  ...,   4.9906,   1.4150,  -1.5373],
#           [ -1.9268,  -2.4359,   1.1982,  ...,   6.1177,   3.7321,  -2.1525],
#           [  5.4670,  -1.1990,   3.5997,  ...,  -0.0320,  -2.1034,   1.7398]]]]), tensor([[[[ 1.9371e+00,  4.5474e-01, -8.3483e-01,  ...,  2.0610e+00,
#             2.4049e+00, -8.8115e-01],
#           [ 1.9950e+00,  3.5203e-01,  4.1112e-01,  ...,  2.5221e+00,
#             2.0610e-01, -1.6837e+00],
#           [-1.2550e-01,  4.1942e-01, -9.7763e-01,  ...,  1.6679e+00,
#             5.4126e-01, -1.2949e+00],
#           [ 1.7466e-01,  1.6530e+00, -3.9172e-01,  ...,  2.7609e+00,
#             2.0967e+00, -1.4005e-01],
#           ...,
#           [-4.6482e+00, -7.6515e-01,  5.3418e+00,  ...,  1.0964e+00,
#            -2.9818e+00,  3.5084e+00],
#           [-1.9854e+00,  1.9740e+00, -2.3376e+00,  ..., -9.0991e-01,
#             1.3885e+00,  2.7645e-01],
#           [-1.6590e+00, -1.5127e+00, -5.5057e+00,  ..., -5.1084e-01,
#             9.4649e-01, -1.2890e+00]],
#
#          [[-3.5674e+00,  2.2271e-02, -1.1492e+00,  ..., -8.5029e-01,
#             1.8361e+00, -1.4877e-01],
#           [-3.3886e+00,  6.3443e-02, -1.0422e+00,  ..., -1.7773e+00,
#             1.9125e+00,  1.3004e-01],
#           [-3.4548e+00, -1.6977e-01,  1.8972e+00,  ..., -3.2138e+00,
#             2.8131e+00, -1.3007e+00],
#           ...,
#           [-3.6720e+00, -2.7050e+00,  1.9419e+00,  ...,  4.4043e-01,
#            -1.8806e+00,  4.6562e+00],
#           [ 1.2055e+00, -1.5142e+00,  3.3118e+00,  ..., -1.7481e+00,
#             8.2240e-01,  3.2370e-01],
#           [ 7.1016e-01, -6.3477e-01,  6.0999e-01,  ...,  1.0380e-01,
#            -6.2528e-01, -2.2574e-01]]]]), tensor([[[[ 7.1145e-02, -1.5234e-01,  4.5927e+00,  ...,  3.0634e+00,
#            -4.5479e+00, -7.8735e+00],
#           [-2.7568e-01,  2.6923e+00,  3.9198e+00,  ...,  4.5891e+00,
#            -6.0305e+00, -7.2941e+00],
#           [-1.7562e+00,  1.7962e+01,  1.4625e+00,  ...,  5.5114e+00,
#            -1.0855e+01,  2.4137e+00],
#           ...,
#           [ 1.3760e+01,  1.1973e+01,  8.4357e+00,  ..., -4.7918e+00,
#            -3.5231e+01, -1.2833e+01],
#           [-1.0127e+01,  1.2656e+01,  9.5460e+00,  ..., -9.2058e+00,
#            -1.1718e+01,  6.2497e+00],
#           [-2.1532e-01,  2.5873e-01,  6.3145e-01,  ...,  1.6320e-01,
#             9.3404e-02, -6.2151e-01]],
#
#          [[-1.1083e+00,  5.6879e-01,  2.9366e-01,  ...,  4.6777e+00,
#            -2.3423e+00,  3.1627e+00],
#           [-2.8136e+00, -4.2873e+00, -2.3793e+00,  ...,  6.8377e+00,
#            -7.3656e-01,  4.4681e+00],
#           [-1.3367e+00, -7.9078e+00,  1.4915e+00,  ...,  2.6948e+00,
#             4.0212e+00,  2.2626e+00],
#           ...,
#           [-7.2823e-01, -9.3829e+00, -1.9890e+01,  ...,  3.8954e+00,
#            -5.7398e+00, -2.6976e+00],
#           [ 2.1879e+00, -1.0685e+01,  2.6528e+00,  ..., -4.7872e-01,
#            -1.7396e+01, -4.2395e+00],
#           [ 6.5857e-01,  5.8675e-01, -9.4295e-01,  ..., -7.0923e-01,
#            -4.8781e-01, -4.0244e-01]],
#
#          [[-8.7875e+00,  3.5939e+00, -2.5374e+00,  ...,  3.5740e+00,
#            -8.5548e-01, -3.5834e+00],
#           [-7.5283e+00,  1.7093e+00, -4.0706e+00,  ...,  5.6284e+00,
#            -2.5184e+00, -2.1498e+00],
#           [-1.2983e+01,  5.9225e+00, -7.7037e-01,  ..., -5.2732e-01,
#            -6.1477e+00,  1.8204e+00],
#           ...,
#           [-3.8751e+00, -6.5393e+00, -2.6671e+00,  ...,  2.8622e+00,
#             7.1227e+00, -7.8388e+00],
#           [-1.3887e+00, -2.0813e+00, -1.3688e+01,  ...,  1.0644e+01,
#            -9.3185e+00, -1.0930e+01],
#           [ 5.2788e-01,  2.9987e-01, -2.0825e-01,  ...,  2.2134e-01,
#             1.7760e+00,  3.7299e-01]],
#
#          ...,
#
#          [[ 3.4627e+00, -6.7345e+00, -4.7201e-01,  ...,  5.2564e+00,
#            -4.5134e+00,  1.8387e+00],
#           [ 1.5769e+00, -4.3151e+00,  3.7683e+00,  ...,  4.4621e+00,
#            -3.5187e+00,  4.0448e-01],
#           [ 7.3411e+00, -4.3596e+00,  1.4281e+00,  ...,  5.9096e+00,
#            -3.9642e+00, -7.8608e-01],
#           ...,
#           [ 4.2133e+00, -4.2792e+00, -5.0005e+00,  ..., -2.4187e-01,
#             4.8800e+00, -1.4241e+01],
#           [ 5.4987e+00,  7.0742e+00,  2.1305e-01,  ...,  6.9970e+00,
#            -2.8427e+00, -4.4546e+00],
#           [-1.0925e-01,  6.2393e-01, -6.1047e-01,  ..., -4.5234e-01,
#            -3.6453e-01,  3.9342e-02]],
#
#          [[-1.2030e+01, -1.6930e+01,  1.2777e+00,  ...,  4.5339e+00,
#            -2.7938e+00, -9.2956e+00],
#           [-6.1220e+00, -1.4651e+01, -2.0523e+00,  ...,  4.2526e+00,
#            -3.2060e+00, -3.7139e+00],
#           [-1.0123e+01, -5.2461e+00, -3.6046e+00,  ..., -3.4357e+00,
#            -5.9496e+00,  1.5344e+00],
#           ...,
#           [-1.0916e+01,  2.3316e+00,  9.2924e+00,  ...,  2.4150e+01,
#            -2.5749e+00, -4.3199e+00],
#           [-6.7367e+00,  4.2543e+00,  8.6250e+00,  ...,  3.0356e-01,
#             5.6935e-01,  8.0866e-01],
#           [-7.9574e-01, -4.2434e-01, -3.1181e-01,  ..., -6.6817e-01,
#             6.7188e-01,  9.3174e-01]],
#
#          [[ 8.3016e-01, -6.0024e-01,  4.0616e+00,  ..., -3.5934e-01,
#             4.6636e-03,  4.1761e+00],
#           [ 7.1654e-01, -4.0572e+00,  4.5244e+00,  ...,  2.4979e+00,
#             2.4110e-01,  6.9844e+00],
#           [-5.8531e-01,  1.0987e+01,  3.4704e+00,  ...,  6.5287e+00,
#             3.0824e+00,  5.6510e+00],
#           ...,
#           [-7.9875e+00,  2.0215e+00, -7.5281e+00,  ..., -3.5149e+00,
#            -1.0629e+00,  4.6079e+00],
#           [-4.6532e+00, -2.5708e+00, -8.2345e+00,  ..., -1.9550e+00,
#             8.8961e-02, -5.8672e+00],
#           [-7.2025e-02,  3.0310e-01,  2.0769e-01,  ...,  4.2118e-04,
#             3.7329e-01,  1.0942e-01]]]]))))

# %%
# Access generated tokens
output.sequences
# Out:
# tensor([[    0,    71, 25941,     6, 10933,  6358,     1]])

# %%
# Decode into words
tokenizer_mario.decode(output.sequences[0], skip_special_tokens=False)
# Out:
# '<pad> A majestic, enormous hall</s>'

# %%
# Access scores associated to each token (excluding the start token 0 = <pad>).
# Returns scores for all possible tokens in each step.
output.scores
# Out:
# (tensor([[-46.9212, -10.5379, -27.4036,  ..., -87.9269, -87.4440, -87.6389]]),
#  tensor([[-30.3731, -12.4038, -24.3930,  ..., -63.0842, -62.7218, -62.9792]]),
#  tensor([[-38.2012, -19.0661, -24.7387,  ..., -80.1341, -79.5276, -79.6145]]),
#  tensor([[-40.1083, -22.2432, -36.1136,  ..., -82.0332, -81.5725, -81.9746]]),
#  tensor([[-44.6734, -20.0176, -34.0707,  ..., -89.7348, -89.2161, -89.3545]]),
#  tensor([[-40.1629,   1.0713, -21.6641,  ..., -72.6069, -72.4596, -72.4369]]))

# %%
# Taking the argmax of each, gives the selected token in each step.
for token_scores in output.scores:
    selected_token = token_scores.argmax()
    print(f"Selected token: {selected_token}, Score: {token_scores[0][selected_token]}, Decoded: {tokenizer_mario.decode(selected_token)}")
# Out:
# Selected token: 71, Score: -4.235823631286621, Decoded: A
# Selected token: 25941, Score: 8.427810668945312, Decoded: majestic
# Selected token: 6, Score: 3.4137935638427734, Decoded: ,
# Selected token: 10933, Score: 8.492544174194336, Decoded: enormous
# Selected token: 6358, Score: 10.149942398071289, Decoded: hall
# Selected token: 1, Score: 1.0712651014328003, Decoded: </s>

# %%
# Function to compute the overall score of the generated sequence by averaging per-token scores.
def get_answer_with_score(question: str, context: str) -> tuple[str, float]:
    """Return the answer to the given question and context together with the score/certainty."""
    input = f"question: {question} context: {context}"
    encoded_input = tokenizer_mario([input], return_tensors='pt')
    # Generate tokens and scores
    output: GenerateEncoderDecoderOutput = model_mario.generate(input_ids=encoded_input.input_ids, attention_mask=encoded_input.attention_mask, return_dict_in_generate=True, output_scores=True)
    # Decode answer
    answer: str = tokenizer_mario.decode(output.sequences[0], skip_special_tokens=True)
    # Compute average per-token score for the answer
    sequence_scores: list[float] = [float(token_scores.max()) for token_scores in output.scores]
    avg_score: float = sum(sequence_scores) / len(sequence_scores)
    # Return answer and score
    return answer, avg_score

question = "What is Valhalla?"
context = "In Norse mythology, Valhalla is a majestic, enormous hall located in Asgard, ruled over by the god Odin."
get_answer_with_score(question, context)
# Out:
# ('A majestic, enormous hall', 4.553255379199982)

# %%
# Use the new scoring function to find the best answer from the different parts of the article
# Use the text parts from above
question = "What are benefits of mobile-env over other simulators?"

answers: list[str] = []
answer_scores: list[float] = []
for text_part in text_parts:
    answer, score = get_answer_with_score(question, text_part)
    answers.append(answer)
    answer_scores.append(score)
    print(answer, "| Score:", score)
# Out:
# It provides sensible default values and can be used out of the box. | Score: 3.1261438528696694
# It is lightweight and fast. | Score: 0.578094516481672
# It provides a useful tool for prototyping and other control algorithms. | Score: 1.636654943227768
# It is simple and lightweight with sensible default values and predefined example scenarios. | Score: 2.472675308585167
# It provides a single-agent user interface. | Score: 2.9955094953378043
# It allows users to simulate complex scenarios. | Score: 1.5019187132517497
# It is more flexible, better documented, and licensed by the standard MIT license. | Score: 2.735137939453125
# It provides an open and simple yet flexible platform for reinforcement learning. | Score: 4.147489632878985
# It provides a more robust network than a traditional s simulation. | Score: 1.422095499932766

# %%
best_score = max(answer_scores)
best_answer = answers[answer_scores.index(best_score)]
best_answer, best_score
# Out:
# ('It provides an open and simple yet flexible platform for reinforcement learning.',
#  4.147489632878985)

# %%
# TODO: Rather than selecting the best answer, try to merge all answers into one coherent answer.
# Eg, with a summarization model.

# %% [markdown]
# #### Summarize answers for individual parts

# %%
answers_str: str = " ".join(answers)
summary_pipeline = pipeline(task="summarization")
summary_pipeline(answers_str)

# Too short for a proper summary. It just takes parts of the text.
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use mps:0
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# Your max_length is set to 142, but your input_length is only 108. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=54)
# [{'summary_text': ' It is simple and lightweight with sensible default values and predefined example scenarios . It is more flexible, better documented, and licensed by the standard MIT license . It provides a more robust network than a traditional s simulation. It is lightweight and fast. It provides an open and simple yet flexible platform for reinforcement learning.'}]
# Error while downloading from https://cdn-lfs.hf.co/sshleifer/distilbart-cnn-12-6/2dd1021c54672b07a4aa2f9eef35107195b2d894792b95f017cca86710f466f0?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27model.safetensors%3B+filename%3D%22model.safetensors%22%3B&Expires=1738695273&Policy=_&Signature=RsD0Vd64amFDvLee49xyIUntkIqVkRndih%7E%7Eq1vE4WZnUsbfk8swN6DAw5rb2EUS0fXFmLIj6SN%7Eq8hrB6ZrzJqQ49%7EpeuEFtQDWYI%7E5H1GsoMqFic4PzTfx552LgTvmDcygyNkT0Lgy4NgrmcUaGy5XoGmRs1AZFrZ5nEVlcdXoRBTBu1t5%7ECggD2gfWabQhd8RLxBys81K4hLG98-BVZgPFTs2GyENLGlmou8o5icofmOrOffU1vv-WcpiwEqKLGHpIDJPG5bIVaX3YgQPMnT14YOy9w8jL1-h6q72RIxBgOuaawNHg45VYDuYuMtV5W9urqXY9955eeCj03-JsQ__&Key-Pair-Id=K3RPWS32NSSJCE: HTTPSConnectionPool(host='cdn-lfs.hf.co', port=443): Read timed out.
# Trying to resume download...

# %% [markdown]
# #### Longformer: Models supporting long sequences/contexts
#
# Longformer: https://huggingface.co/docs/transformers/model_doc/longformer
#
# LED (Longformer Encoder-Decoder), which is preferrable for generative Q&A:
# https://huggingface.co/docs/transformers/model_doc/led
#
#
# It seems like there is no available LED model that's already fine-tuned to Q&A.
# Instead, I found one that's fine-tuned to summarizing Arxiv articles:
# https://huggingface.co/allenai/led-large-16384-arxiv

# %%
# https://huggingface.co/allenai/led-large-16384-arxiv
from transformers import LEDForConditionalGeneration, LEDTokenizer

tokenizer = LEDTokenizer.from_pretrained("allenai/led-large-16384-arxiv")

input_ids = tokenizer(full_text, return_tensors="pt").input_ids

global_attention_mask = torch.zeros_like(input_ids)
# set global_attention_mask on first token
global_attention_mask[:, 0] = 1

model = LEDForConditionalGeneration.from_pretrained("allenai/led-large-16384-arxiv") #, return_dict_in_generate=True)
sequences = model.generate(input_ids, global_attention_mask=global_attention_mask)
summary = tokenizer.decode(sequences[0])
summary

# The summary are just parts of the abstract!
# Out:
# Input ids are automatically padded from 4550 to 5120 to be a multiple of `config.attention_window`: 1024
# model.safetensors:   0%|          | 0.00/1.84G [00:00<?, ?B/s]
# '</s> we propose mobile-env , a simple and open platform for training , evaluating , and comparing reinforcement learning and conventional approaches for continuous control in wireless mobile networks . \n mobile-env is lightweight and implements the common OpenAI Gym interface and additional wrappers , which allows connecting virtually any single-agent or multi-agent reinforcement learning framework to the environment . \n mobile-env provides sensible default values and can be used out of the box , it also has many conﬁguration options and is easy to extend . \n thanks to its modular architecture , it is also easy to adjust and extend . \n we hope mobile-env will serve as a useful tool for training and evaluating new reinforcement learning approaches as well as benchmarking existing approaches . </s>'
# Error while downloading from https://cdn-lfs.hf.co/allenai/led-large-16384-arxiv/2b4f0a0405c2ab2300880492a634ccb639b5310ca1a4356c9b385cc5090375d1?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27model.safetensors%3B+filename%3D%22model.safetensors%22%3B&Expires=1738695287&Policy=_&Signature=UxvU0w7dc4tK5vOWaCL2ghzgxqHzIUU2tJiGu89JHYrZ32A3F2XnAWe9bxkzYDzxRl8i38GBoWa1gZ%7E1UiFzadpQ6-XbRSxvHyLBt3qBWhCEIIFOszsIVcBGGkQOV9so3bWSsZgI4uMsHjeRi88khbAe%7EzYTg10KxDKVY%7EZMp3NxVjenMLqQZj7KnDc4ZgFRVg4jC-u5dQ6BIYwEXqXMSn3k0sA-%7ED1fMpwQR3QJQs9c1k98DwTjcLg8lWIQdUADHQHmaP-8C6gObCFESsSrJ0lBK%7ELMUMA3i4c3zS4FWkY%7Ed3wPe8Wxr1emFOcYUPXBrFvon3SF2Jat4Eeq91Q-4g__&Key-Pair-Id=K3RPWS32NSSJCE: HTTPSConnectionPool(host='cdn-lfs.hf.co', port=443): Read timed out.
# Trying to resume download...

# %%
# Try Q&A with the pre-trained LED model, even though it's not fine-tuned for Q&A
led_qa = pipeline(task="text2text-generation", model="allenai/led-large-16384-arxiv")
input_text = f"{full_text} Given this context, please answer the following question. {question}"
print(f"Question: {question}")
led_qa(input_text)
# Pretty bad answer
# Out:
# Device set to use mps:0
# Input ids are automatically padded from 4572 to 5120 to be a multiple of `config.attention_window`: 1024
# [{'generated_text': ' we proposemobile-env , a simple and open platform for training , evaluating , and comparing reinforcement learning and conventional approaches for continuous control in wireless mobile networks . \n mobile-env is lightweight and implements the common openAI Gym interface and additional wrappers , which allows connecting virtually any single-agent or multi-agent reinforcement learning framework to the environment . \n mobile-env provides sensible default values and can be used out-of the box , it also has many conﬁguration options and is easy to \n extend. we therefore believe mobile-env to be a valuable platform for driving meaningful progress in autonomous coordination of wireless mobile networks . '}]

# %%
# Try BART fine-tuned on ELI5 for generative Q&A
bart_eli5 = pipeline("text2text-generation", model="vblagoje/bart_lfqa")
query = f"question: {question} context: {full_text}"
print(f"Question: {question}")
bart_eli5(input_text)
# Out:
# Device set to use mps:0
# Token indices sequence length is longer than the specified maximum sequence length for this model (4572 > 1024). Running this sequence through the model will result in indexing errors
# Question: What are benefits of mobile-env over other simulators?
# [{'generated_text': "I'm not sure if this is the right subreddit for this, but I'm curious as well"}]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# TODO: Feed summary into one of the Q&A models above
